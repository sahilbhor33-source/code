# %%
# ==========================================
# DNN Library Demo (Corrected Code)
# ==========================================

# Import Libraries
import pandas as pd
import numpy as np   # ✅ FIXED (np defined)
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Student Info
print("Suyash Jagtap")
print("PRN : 20250804077")

# Create Dataset
data = {
    'x': [1, 2, 3, 4, 5, 6],
    'Y': [2, 4, 6, 8, 10, 12]
}

df = pd.DataFrame(data)

print("Dataset:\n", df.head())

# Prepare Data
X = np.array(df['x']).reshape(-1, 1)
Y = np.array(df['Y'])

# Train-Test Split
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

# Feature Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)   # ✅ FIXED (was x_test)

# Build Model
model = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(1)
])

# Compile Model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train Model
model.fit(X_train, Y_train, epochs=50, verbose=0)

# Predictions
predictions = model.predict(X_test)
print("Predictions:", predictions)

# Plot Results
plt.scatter(X, Y, label="Actual Data")
plt.plot(X, model.predict(scaler.transform(X)), label="Prediction", color='red')
plt.legend()
plt.title("DNN Library Demo")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# Vrushali Pardeshi
# PRN : 20250804088
# Dataset:
#     x   Y
# 0  1   2
# 1  2   4
# 2  3   6
# 3  4   8
# 4  5  10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Predictions: [[-3.3096533]
#  [-2.3497622]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
